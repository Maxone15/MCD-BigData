# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('../files/QQP_2015/csv/012015.csv')
# df.columns = ['PRODUCTO','PRESENTACIÓN','MARCA','CATEGORÍA','CATÁLOGO','PRECIO','FECHAREGISTRO','CADENACOMERCIAL','GIRO',
#               'NOMBRECOMERCIAL','DIRECCIÓN','ESTADO','MUNICIPIO','LATITUD','LONGITUD']
df.columns = ['PRODUCT', 'PRESENTATION', 'BRAND', 'CATEGORY', 'CATALOG', 'PRICE', 'REGISTRATION_DATE', 'COMMERCIAL_CHAIN', 'BUSINESS_LINE',
              'COMMERCIAL_NAME', 'ADDRESS', 'STATE', 'MUNICIPALITY', 'LATITUDE', 'LONGITUDE']
df
# Out:
#                        PRODUCT  \
# 0                    BATIDORAS
# 1                    BATIDORAS
# 2                    BATIDORAS
# 3                    BATIDORAS
# 4                    CAFETERAS
# ...                        ...
# 53739         TORTILLA DE MAIZ
# 53740         TORTILLA DE MAIZ
# 53741       LECHE PASTEURIZADA
# 53742  LECHE ULTRAPASTEURIZADA
# 53743         TORTILLA DE MAIZ
#
#                                             PRESENTATION  \
# 0      2532 Ó 2532-013. MANUAL. 6 VELOCIDADES. SIN TAZON
# 1      2614 O 2614-13. DE INMERSION. 2 VELOCIDADES. S...
# 2      2700 O 2700-013. PEDESTAL. 12 VELOCIDADES. TAZ...
# 3      FPSTHS2611 Ó FPSTHS2611-013. MANUAL Y PEDESTAL...
# 4                           FG4105ME. CAPACIDAD 10 TAZAS
# ...                                                  ...
# 53739                                       1 KG. GRANEL
# 53740                                       1 KG. GRANEL
# 53741                                         CAJA 1 LT.
# 53742                                         CAJA 1 LT.
# 53743                                       1 KG. GRANEL
#
#                              BRAND                        CATEGORY  \
# 0                            OSTER             APARATOS ELECTRICOS
# 1                            OSTER             APARATOS ELECTRICOS
# 2                            OSTER             APARATOS ELECTRICOS
# 3                            OSTER             APARATOS ELECTRICOS
# 4      MOULINEX. HELIORA SELECTIVE             APARATOS ELECTRICOS
# ...                            ...                             ...
# 53739                          S/M  TORTILLAS Y DERIVADOS DEL MAIZ
# 53740                          S/M  TORTILLAS Y DERIVADOS DEL MAIZ
# 53741                 LALA. ENTERA                    LECHE FRESCA
# 53742                 LALA. ENTERA                 LECHE PROCESADA
# 53743                          S/M  TORTILLAS Y DERIVADOS DEL MAIZ
#
#                  CATALOG    PRICE REGISTRATION_DATE  \
# 0      ELECTRODOMESTICOS   441.15        2015-01-02
# 1      ELECTRODOMESTICOS   424.15        2015-01-02
# 2      ELECTRODOMESTICOS  2591.65        2015-01-02
# 3      ELECTRODOMESTICOS   721.65        2015-01-02
# 4      ELECTRODOMESTICOS   559.20        2015-01-02
# ...                  ...      ...               ...
# 53739            BASICOS    11.50        2015-01-02
# 53740            BASICOS    10.00        2015-01-02
# 53741            BASICOS    14.40        2015-01-02
# 53742            BASICOS    15.50        2015-01-02
# 53743            BASICOS    10.00        2015-01-02
#
#                  COMMERCIAL_CHAIN           BUSINESS_LINE  \
# 0                       LIVERPOOL  TIENDA DEPARTAMENTALES
# 1                       LIVERPOOL  TIENDA DEPARTAMENTALES
# 2                       LIVERPOOL  TIENDA DEPARTAMENTALES
# 3                       LIVERPOOL  TIENDA DEPARTAMENTALES
# 4                       LIVERPOOL  TIENDA DEPARTAMENTALES
# ...                           ...                     ...
# 53739  TORTILLERIAS TRADICIONALES            TORTILLERÍAS
# 53740  TORTILLERIAS TRADICIONALES            TORTILLERÍAS
# 53741                    WAL-MART            TORTILLERÍAS
# 53742                    WAL-MART            TORTILLERÍAS
# 53743                    WAL-MART            TORTILLERÍAS
#
#                          COMMERCIAL_NAME  \
# 0      LIVERPOOL SUCURSAL AGUASCALIENTES
# 1      LIVERPOOL SUCURSAL AGUASCALIENTES
# 2      LIVERPOOL SUCURSAL AGUASCALIENTES
# 3      LIVERPOOL SUCURSAL AGUASCALIENTES
# 4      LIVERPOOL SUCURSAL AGUASCALIENTES
# ...                                  ...
# 53739              TORTILLERIA INFOVANIT
# 53740        TORTILLERIA SAGRADO CORAZON
# 53741                           WAL MART
# 53742                           WAL MART
# 53743                           WAL MART
#
#                                                  ADDRESS           STATE  \
# 0      ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES ...  AGUASCALIENTES
# 1      ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES ...  AGUASCALIENTES
# 2      ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES ...  AGUASCALIENTES
# 3      ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES ...  AGUASCALIENTES
# 4      ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES ...  AGUASCALIENTES
# ...                                                  ...             ...
# 53739   GAVILANES No. 205, COL. LOS GAVILANES, CP. 98600       ZACATECAS
# 53740  DEL IDEAL  206, C.FELIX U. GOMEZ Y C. YANGUAS,...       ZACATECAS
# 53741  FRANCISCO GARCIA SALINAS NO. 202, COL. FRACCIO...       ZACATECAS
# 53742  FRANCISCO GARCIA SALINAS NO. 202, COL. FRACCIO...       ZACATECAS
# 53743  FRANCISCO GARCIA SALINAS NO. 202, COL. FRACCIO...       ZACATECAS
#
#          MUNICIPALITY   LATITUDE   LONGITUDE
# 0      AGUASCALIENTES  21.924271 -102.289721
# 1      AGUASCALIENTES  21.924271 -102.289721
# 2      AGUASCALIENTES  21.924271 -102.289721
# 3      AGUASCALIENTES  21.924271 -102.289721
# 4      AGUASCALIENTES  21.924271 -102.289721
# ...               ...        ...         ...
# 53739       ZACATECAS        NaN         NaN
# 53740       ZACATECAS  22.775123 -102.575548
# 53741       ZACATECAS        NaN         NaN
# 53742       ZACATECAS        NaN         NaN
# 53743       ZACATECAS        NaN         NaN
#
# [53744 rows x 15 columns]
