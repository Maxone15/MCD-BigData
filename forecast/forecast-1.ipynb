# %%
import pandas as pd
import plotly.graph_objects as go
import warnings
from statsmodels.graphics import tsaplots
warnings.filterwarnings("ignore")

# %%
df = pd.read_parquet('data/qqp_agg.snappy.parquet')
df.head()
# Out:
#         fecha  fecha_year  fecha_month            producto  \
# 0  2015-01-09        2015            1              AZUCAR
# 1  2015-02-06        2015            2             MANZANA
# 2  2015-07-13        2015            7  LECHE PASTEURIZADA
# 3  2015-11-18        2015           11              ACEITE
# 4  2016-01-15        2016            1           CARNE RES
#
#                             descripcion  count_marca  count_tiendas  \
# 0         BOLSA PLASTICO 2 KG. REFINADA            1             34
# 1                          1 KG. GOLDEN            1             55
# 2                            CAJA 1 LT.            1            105
# 3                 BOTELLA 946 ML. MIXTO            1             47
# 4  1 KG. GRANEL. FALDA O PARA DESHEBRAR            1             55
#
#    count_estados  count_municipios  precio_avg  precio_desv_std precio_median  \
# 0             22                29   33.829412         3.776986         35.00
# 1             28                40   26.500000         5.792796         25.95
# 2             22                40   13.909512         1.089266         14.20
# 3             24                35   21.236809         2.807200         21.75
# 4             27                36  135.869091         8.076002        135.90
#
#   precio_max precio_min
# 0      38.50      24.50
# 1      40.00      15.00
# 2      16.70      10.00
# 3      26.50      16.00
# 4     159.00     105.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51733 entries, 0 to 51732
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha             51733 non-null  object
#  1   fecha_year        51733 non-null  int32
#  2   fecha_month       51733 non-null  int32
#  3   producto          51733 non-null  object
#  4   descripcion       51733 non-null  object
#  5   count_marca       51733 non-null  int64
#  6   count_tiendas     51733 non-null  int64
#  7   count_estados     51733 non-null  int64
#  8   count_municipios  51733 non-null  int64
#  9   precio_avg        51733 non-null  object
#  10  precio_desv_std   51522 non-null  float64
#  11  precio_median     51733 non-null  object
#  12  precio_max        51733 non-null  object
#  13  precio_min        51733 non-null  object
# dtypes: float64(1), int32(2), int64(4), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ### Exploratory and clean data

# %%
## agregamos los datos de los diferentes productos para tener el total de la canasta basica por fecha
df['fecha'] = pd.to_datetime(df['fecha'])

df_agg = df.groupby('fecha')['precio_avg'].sum().reset_index()
df_agg.rename(columns={'fecha': 'ds', 'precio_avg': 'y'}, inplace=True)
df_agg = df_agg[df_agg['ds'] < '2023-08-01'] ## para eliminar inestabilidad ** (revisar con el equipo)
df_agg.head()
# Out:
#           ds           y
# 0 2015-01-02  639.162270
# 1 2015-01-05  641.555843
# 2 2015-01-06  627.111015
# 3 2015-01-07  636.623308
# 4 2015-01-08  645.458136

# %%
### Visualizamos los datos y también añadimos bandas para detectar outliers
df_agg["SMA_30"] = df_agg["y"].rolling(window=30).mean()
df_agg["STD_30"] = df_agg["y"].rolling(window=30).std()


df_agg["Upper_Band"] = df_agg["SMA_30"] + (df_agg["STD_30"] * 3)
df_agg["Lower_Band"] = df_agg["SMA_30"] - (df_agg["STD_30"] * 3)

df_agg["Outlier"] = (df_agg["y"] > df_agg["Upper_Band"]) | (df_agg["y"] < df_agg["Lower_Band"])

fig = go.Figure()
fig.add_trace(go.Scatter(x=df_agg["ds"], y=df_agg["y"], mode='lines', name='Datos originales'))
fig.add_trace(go.Scatter(x=df_agg["ds"], y=df_agg["SMA_30"], mode='lines', name='SMA 30 días'))

fig.add_trace(go.Scatter(
    x=pd.concat([df_agg["ds"], df_agg["ds"][::-1]]), 
    y=pd.concat([df_agg["Upper_Band"], df_agg["Lower_Band"][::-1]]),
    fill='toself',
    fillcolor='rgba(0, 176, 246, 0.3)',  
    line=dict(color='rgba(255,255,255,0)'),
    name='Bandas',
    showlegend=False
))


fig.add_trace(go.Scatter(
    x=df_agg[df_agg["Outlier"]]["ds"], 
    y=df_agg[df_agg["Outlier"]]["y"], 
    mode='markers', 
    marker=dict(color='red', size=6),
    name='Outliers'
))


fig.update_layout(
    title='Medias Móviles y Bandas de Desviación Estándar (30 días)',
    xaxis_title='Fecha',
    yaxis_title='Precio Canasta báscia',
    height=800 
)


fig.show()

# %%
## construimos otro dataframe con los datos limpios, imputamos outliers con SMA y también creamos el date range completo
df_agg["yclean"] = df_agg["y"]
df_agg.loc[df_agg["Outlier"], "yclean"] = df_agg["SMA_30"]
min_date = df_agg["ds"].min()
max_date = df_agg["ds"].max()

date_range = pd.date_range(start=min_date, end=max_date, freq='D')
df_agg2 = pd.DataFrame(date_range, columns=["ds"])
df_agg2 = df_agg2.merge(df_agg[["ds", "yclean"]], on="ds", how="left")

df_agg2.head(10)
# Out:
#           ds      yclean
# 0 2015-01-02  639.162270
# 1 2015-01-03         NaN
# 2 2015-01-04         NaN
# 3 2015-01-05  641.555843
# 4 2015-01-06  627.111015
# 5 2015-01-07  636.623308
# 6 2015-01-08  645.458136
# 7 2015-01-09  634.013979
# 8 2015-01-10         NaN
# 9 2015-01-11         NaN

# %%
## imputamos los nulos generado al completar el date range
rolling_mean = df_agg2['yclean'].rolling(window=5, min_periods=1).mean()
df_agg2['yclean'] = df_agg2['yclean'].combine_first(rolling_mean.shift())
df_agg2.rename(columns={'yclean': 'y'}, inplace=True)
df_agg2.head(20)
# Out:
#            ds           y
# 0  2015-01-02  639.162270
# 1  2015-01-03   639.16227
# 2  2015-01-04   639.16227
# 3  2015-01-05  641.555843
# 4  2015-01-06  627.111015
# 5  2015-01-07  636.623308
# 6  2015-01-08  645.458136
# 7  2015-01-09  634.013979
# 8  2015-01-10  636.952456
# 9  2015-01-11  635.801609
# 10 2015-01-12  639.706005
# 11 2015-01-13  623.551205
# 12 2015-01-14  634.881468
# 13 2015-01-15  640.786293
# 14 2015-01-16  636.780306
# 15 2015-01-17  635.141055
# 16 2015-01-18  633.999818
# 17 2015-01-19  637.797960
# 18 2015-01-20  622.754727
# 19 2015-01-21  634.552496

# %%
## agregamos los datos de manera semanal
df_agg2['y'] = pd.to_numeric(df_agg2['y'], errors='coerce')

df_agg2.set_index('ds', inplace=True)
df_weekly = df_agg2.resample('W').mean().reset_index()
df_weekly.head(20)
# Out:
#            ds           y
# 0  2015-01-04  639.162270
# 1  2015-01-11  636.788050
# 2  2015-01-18  634.978021
# 3  2015-01-25  634.043947
# 4  2015-02-01  637.521832
# 5  2015-02-08  636.747428
# 6  2015-02-15  629.861775
# 7  2015-02-22  628.705048
# 8  2015-03-01  626.897860
# 9  2015-03-08  622.362914
# 10 2015-03-15  619.047934
# 11 2015-03-22  626.121584
# 12 2015-03-29  632.259307
# 13 2015-04-05  626.121157
# 14 2015-04-12  630.126587
# 15 2015-04-19  632.123703
# 16 2015-04-26  631.771558
# 17 2015-05-03  629.924547
# 18 2015-05-10  637.274264
# 19 2015-05-17  635.720448

# %%
df_weekly["SMA_4"] = df_weekly["y"].rolling(window=4).mean()
df_weekly["STD_4"] = df_weekly["y"].rolling(window=4).std()

df_weekly["Upper_Band"] = df_weekly["SMA_4"] + (df_weekly["STD_4"] * 3)
df_weekly["Lower_Band"] = df_weekly["SMA_4"] - (df_weekly["STD_4"] * 3)

fig = go.Figure()

fig.add_trace(go.Scatter(x=df_weekly["ds"], y=df_weekly["y"], mode='lines', name='Datos originales'))
fig.add_trace(go.Scatter(x=df_weekly["ds"], y=df_weekly["SMA_4"], mode='lines', name='SMA 4 semanas'))


fig.add_trace(go.Scatter(
    x=pd.concat([df_weekly["ds"], df_weekly["ds"][::-1]]), 
    y=pd.concat([df_weekly["Upper_Band"], df_weekly["Lower_Band"][::-1]]),
    fill='toself',
    fillcolor='rgba(0, 176, 246, 0.5)', 
    line=dict(color='rgba(255,255,255,0)'),
    name='Bandas',
    showlegend=False
))

fig.update_layout(
    title='Medias Móviles y Bandas de Desviación Estándar (4 semanas)',
    xaxis_title='Fecha',
    yaxis_title='Precio Canasta Básica (Semanal)',
    height=800 
)

fig.show()

# %%
fig = tsaplots.plot_acf(df_weekly["y"],lags=52)

# %% [markdown]
# ### Prophet + Optuna

# %%
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import optuna
from prophet.diagnostics import cross_validation,performance_metrics
from prophet.plot import plot_cross_validation_metric

# %%
def objective(trial):
    interval_width = trial.suggest_float('interval_width', 0.8, 0.99)
    changepoint_prior_scale = trial.suggest_float('changepoint_prior_scale', 0.01, 0.8)
    n_changepoints = trial.suggest_int('n_changepoints', 10, 30)
    seasonality_mode = trial.suggest_categorical('seasonality_mode', ['additive', 'multiplicative'])
    seasonality_prior_scale = trial.suggest_float('seasonality_prior_scale', 0.01, 10.0)
    holidays_prior_scale = trial.suggest_float('holidays_prior_scale', 8.00, 20.0)
    fourier_order = trial.suggest_int('fourier_order', 1, 20)
    
    
    model = Prophet(
        interval_width=interval_width,
        changepoint_prior_scale=changepoint_prior_scale,
        n_changepoints=n_changepoints,
        weekly_seasonality=True,
        seasonality_mode=seasonality_mode,
        seasonality_prior_scale=seasonality_prior_scale,
        holidays_prior_scale=holidays_prior_scale,
    )
    
    model.add_seasonality(name='yearly', period=30.5, fourier_order=fourier_order)

    model.fit(train_data)
    
    future = model.make_future_dataframe(periods=len(test_data), freq='W')
    forecast = model.predict(future)
    
    forecast_valid = forecast[forecast['ds'].isin(test_data['ds'])]
    
    y_true = test_data['y'].values
    y_pred = forecast_valid['yhat'].values
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    return rmse

# %%
## Split data
train_data = df_weekly[df_weekly['ds'] < '2022-01-01']
test_data = df_weekly[df_weekly['ds'] >= '2022-01-01']

train_data = train_data.loc[:, ['ds', 'y']]
test_data = test_data.loc[:, ['ds', 'y']]

print("Train data size:")
print(train_data.shape[0])
print("\nTest data size:")
print(test_data.shape[0])
# Out:
# Train data size:
# 365
#
# Test data size:
# 84

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-05-30 02:57:40,611] A new study created in memory with name: no-name-fb9098c5-c3fe-4654-8829-447ec1455802
# 02:57:40 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:40 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:40,818] Trial 0 finished with value: 92.38601267011232 and parameters: {'interval_width': 0.9753407305666127, 'changepoint_prior_scale': 0.16680462760327672, 'n_changepoints': 17, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 5.856796815480806, 'holidays_prior_scale': 10.193768541242163, 'fourier_order': 4}. Best is trial 0 with value: 92.38601267011232.
# 02:57:40 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:41 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:41,090] Trial 1 finished with value: 90.94741589155639 and parameters: {'interval_width': 0.9249177422269369, 'changepoint_prior_scale': 0.10579880772800257, 'n_changepoints': 19, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.7789126703917784, 'holidays_prior_scale': 18.918715343083992, 'fourier_order': 20}. Best is trial 1 with value: 90.94741589155639.
# 02:57:41 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:41 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:41,488] Trial 2 finished with value: 92.64506283388637 and parameters: {'interval_width': 0.8981982720947173, 'changepoint_prior_scale': 0.5806808430086221, 'n_changepoints': 18, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 5.9500762143484085, 'holidays_prior_scale': 18.19055370799528, 'fourier_order': 15}. Best is trial 1 with value: 90.94741589155639.
# 02:57:41 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:41 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:41,850] Trial 3 finished with value: 95.48147414327904 and parameters: {'interval_width': 0.9179756723489799, 'changepoint_prior_scale': 0.19701796567575577, 'n_changepoints': 26, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 3.7251856267121264, 'holidays_prior_scale': 14.569969711040326, 'fourier_order': 4}. Best is trial 1 with value: 90.94741589155639.
# 02:57:41 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:42 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:42,086] Trial 4 finished with value: 95.68743915677739 and parameters: {'interval_width': 0.8559721740081149, 'changepoint_prior_scale': 0.7001267498064407, 'n_changepoints': 14, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 2.139932582371701, 'holidays_prior_scale': 14.40351203862405, 'fourier_order': 12}. Best is trial 1 with value: 90.94741589155639.
# 02:57:42 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:42 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:42,230] Trial 5 finished with value: 68.66910346660859 and parameters: {'interval_width': 0.8475387743395315, 'changepoint_prior_scale': 0.015837032948798922, 'n_changepoints': 24, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 3.367632798500384, 'holidays_prior_scale': 18.411294303984906, 'fourier_order': 12}. Best is trial 5 with value: 68.66910346660859.
# 02:57:42 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:42 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:42,472] Trial 6 finished with value: 95.35304345332885 and parameters: {'interval_width': 0.895382096441708, 'changepoint_prior_scale': 0.4317259187899547, 'n_changepoints': 15, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 4.115638797713262, 'holidays_prior_scale': 17.117579143221622, 'fourier_order': 5}. Best is trial 5 with value: 68.66910346660859.
# 02:57:42 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:42 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:42,712] Trial 7 finished with value: 94.08611004015916 and parameters: {'interval_width': 0.8269692657710696, 'changepoint_prior_scale': 0.5954046795744797, 'n_changepoints': 20, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 9.035830300806213, 'holidays_prior_scale': 10.094260798105191, 'fourier_order': 20}. Best is trial 5 with value: 68.66910346660859.
# 02:57:42 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:42 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57
- cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:50,092] Trial 37 finished with value: 95.0692343897717 and parameters: {'interval_width': 0.8351462199339537, 'changepoint_prior_scale': 0.5037969722637737, 'n_changepoints': 27, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 3.3216703373344107, 'holidays_prior_scale': 12.209410954803953, 'fourier_order': 9}. Best is trial 31 with value: 59.279621317081414.
# 02:57:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:50 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:50,302] Trial 38 finished with value: 93.93500763097397 and parameters: {'interval_width': 0.8186053323120338, 'changepoint_prior_scale': 0.22728613106714846, 'n_changepoints': 22, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 9.338832372314831, 'holidays_prior_scale': 11.540593751185131, 'fourier_order': 6}. Best is trial 31 with value: 59.279621317081414.
# 02:57:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:50 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:50,659] Trial 39 finished with value: 95.2719631024986 and parameters: {'interval_width': 0.8904481309556564, 'changepoint_prior_scale': 0.6653379229824947, 'n_changepoints': 29, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 8.270299301605688, 'holidays_prior_scale': 16.576019034331843, 'fourier_order': 11}. Best is trial 31 with value: 59.279621317081414.
# 02:57:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:50 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:50,854] Trial 40 finished with value: 81.8596173479701 and parameters: {'interval_width': 0.852545959984443, 'changepoint_prior_scale': 0.05340819556469105, 'n_changepoints': 15, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 5.48122360975227, 'holidays_prior_scale': 15.399038575102443, 'fourier_order': 13}. Best is trial 31 with value: 59.279621317081414.
# 02:57:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:50 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:51,056] Trial 41 finished with value: 79.49569964890274 and parameters: {'interval_width': 0.9014353694927072, 'changepoint_prior_scale': 0.039644460125804325, 'n_changepoints': 24, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.058106475433819, 'holidays_prior_scale': 18.056392319967085, 'fourier_order': 13}. Best is trial 31 with value: 59.279621317081414.
# 02:57:51 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:51 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:51,233] Trial 42 finished with value: 69.81109744629013 and parameters: {'interval_width': 0.8633802739636041, 'changepoint_prior_scale': 0.01675806974684446, 'n_changepoints': 25, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 6.998721542603036, 'holidays_prior_scale': 17.350873789298532, 'fourier_order': 12}. Best is trial 31 with value: 59.279621317081414.
# 02:57:51 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:51 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:51,460] Trial 43 finished with value: 92.06970819372441 and parameters: {'interval_width': 0.8668032812549807, 'changepoint_prior_scale': 0.11265837206911558, 'n_changepoints': 26, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 6.2639236443040325, 'holidays_prior_scale': 17.231446233555616, 'fourier_order': 8}. Best is trial 31 with value: 59.279621317081414.
# 02:57:51 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:51 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:51,674] Trial 44 finished with value: 74.52970536904036 and parameters: {'interval_width': 0.85154137184226, 'changepoint_prior_scale': 0.02204246421501462, 'n_changepoints': 27, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.2977163109584, 'holidays_prior_scale': 16.41525318606114, 'fourier_order': 12}. Best is trial 31 with value: 59.279621317081414.
# 02:57:51 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:51 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:51,927] Trial 45 finished with value: 92.30713599895202 and parameters: {'interval_width': 0.8396284571835826, 'changepoint_prior_scale': 0.13464004123432177, 'n_changepoints': 25, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.532149056245829, 'holidays_prior_scale': 14.239082115386315, 'fourier_order': 10}. Best is trial 31 with value: 59.279621317081414.
# 02:57:51 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:52 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57:52,151] Trial 46 finished with value: 86.47154586469478 and parameters: {'interval_width': 0.8602429526929272, 'changepoint_prior_scale': 0.058156753521692264, 'n_changepoints': 21, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.038399110498859024, 'holidays_prior_scale': 18.580626514571794, 'fourier_order': 9}. Best is trial 31 with value: 59.279621317081414.
# 02:57:52 - cmdstanpy - INFO - Chain [1] start processing
# 02:57:52 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:57
 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.954028250400583, 'holidays_prior_scale': 15.593077068443105, 'fourier_order': 12}. Best is trial 58 with value: 58.536885003350264.
# 02:58:00 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:00 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:00,743] Trial 86 finished with value: 93.39485687328632 and parameters: {'interval_width': 0.9405323217826803, 'changepoint_prior_scale': 0.08487651930588122, 'n_changepoints': 25, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 8.493601201187293, 'holidays_prior_scale': 16.181536264759863, 'fourier_order': 14}. Best is trial 58 with value: 58.536885003350264.
# 02:58:00 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:00 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:00,962] Trial 87 finished with value: 91.27765813769804 and parameters: {'interval_width': 0.8976105233350419, 'changepoint_prior_scale': 0.11731315901799184, 'n_changepoints': 22, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.7707712527019766, 'holidays_prior_scale': 16.622851843561758, 'fourier_order': 12}. Best is trial 58 with value: 58.536885003350264.
# 02:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:01 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:01,135] Trial 88 finished with value: 59.13968282728513 and parameters: {'interval_width': 0.8746956172996346, 'changepoint_prior_scale': 0.01042786996288569, 'n_changepoints': 18, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 8.196346144610214, 'holidays_prior_scale': 17.356653688422057, 'fourier_order': 11}. Best is trial 58 with value: 58.536885003350264.
# 02:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:01 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:01,408] Trial 89 finished with value: 85.76239575608601 and parameters: {'interval_width': 0.9301559213480581, 'changepoint_prior_scale': 0.0537699656073721, 'n_changepoints': 16, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 9.21142335776686, 'holidays_prior_scale': 16.075899582013594, 'fourier_order': 11}. Best is trial 58 with value: 58.536885003350264.
# 02:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:01 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:01,787] Trial 90 finished with value: 92.60654607625047 and parameters: {'interval_width': 0.8749571247887051, 'changepoint_prior_scale': 0.031528368328222575, 'n_changepoints': 19, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 8.14509026238052, 'holidays_prior_scale': 16.757940260957206, 'fourier_order': 10}. Best is trial 58 with value: 58.536885003350264.
# 02:58:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:01 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:01,959] Trial 91 finished with value: 63.199777255210954 and parameters: {'interval_width': 0.8675822426802456, 'changepoint_prior_scale': 0.013819596957046537, 'n_changepoints': 18, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.430748347081091, 'holidays_prior_scale': 17.461439913922643, 'fourier_order': 12}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:02,135] Trial 92 finished with value: 84.85386260318995 and parameters: {'interval_width': 0.8682744491921037, 'changepoint_prior_scale': 0.052218762963073394, 'n_changepoints': 18, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.560728279706927, 'holidays_prior_scale': 17.259647961328405, 'fourier_order': 11}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:02,303] Trial 93 finished with value: 77.23525400878502 and parameters: {'interval_width': 0.8484488624057628, 'changepoint_prior_scale': 0.03425096250141049, 'n_changepoints': 17, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 8.54030129930012, 'holidays_prior_scale': 17.196221456573745, 'fourier_order': 13}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:02,490] Trial 94 finished with value: 87.23001966386462 and parameters: {'interval_width': 0.9189033322610136, 'changepoint_prior_scale': 0.07406851631283905, 'n_changepoints': 16, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.319596158681082, 'holidays_prior_scale': 18.853529652659883, 'fourier_order': 11}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:02,663] Trial 95 finished with value: 80.2617196084759 and parameters: {'interval_width': 0.8586067774701093, 'changepoint_prior_scale': 0.028456625812348906, 'n_changepoints': 20, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 8.967281761575215, 'holidays_prior_scale': 19.30266241940861, 'fourier_order': 10}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:02,835] Trial 96 finished with value: 61.17684762553208 and parameters: {'interval_width': 0.8628069375050726, 'changepoint_prior_scale': 0.010763937848992676, 'n_changepoints': 18, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.8061522632191425, 'holidays_prior_scale': 17.392784024355336, 'fourier_order': 12}. Best is trial 58 with value: 58.536885003350264.
# 02:58:02 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:02 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:03,045] Trial 97 finished with value: 82.85359372009029 and parameters: {'interval_width': 0.8404431154481022, 'changepoint_prior_scale': 0.05451824926756549, 'n_changepoints': 27, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.842470009077499, 'holidays_prior_scale': 18.56975385372686, 'fourier_order': 15}. Best is trial 58 with value: 58.536885003350264.
# 02:58:03 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:03 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:03,315] Trial 98 finished with value: 89.22815948138629 and parameters: {'interval_width': 0.8632217572335155, 'changepoint_prior_scale': 0.08106769798867766, 'n_changepoints': 19, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 8.270325072522851, 'holidays_prior_scale': 14.496060733001901, 'fourier_order': 14}. Best is trial 58 with value: 58.536885003350264.
# 02:58:03 - cmdstanpy - INFO - Chain [1] start processing
# 02:58:03 - cmdstanpy - INFO - Chain [1] done processing
# [I 2024-05-30 02:58:03,539] Trial 99 finished with value: 92.56357143668058 and parameters: {'interval_width': 0.8857020410970277, 'changepoint_prior_scale': 0.14673348741579784, 'n_changepoints': 25, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.01327148642323, 'holidays_prior_scale': 19.73808921553333, 'fourier_order': 11}. Best is trial 58 with value: 58.536885003350264.

# %%
best_params = study.best_params
print('Best Metric: ', study.best_value)
print('Best params: ', study.best_params)
# Out:
# Best Metric:  58.536885003350264
# Best params:  {'interval_width': 0.8949954517700941, 'changepoint_prior_scale': 0.0109953376690951, 'n_changepoints': 24, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 7.547806237038662, 'holidays_prior_scale': 19.35300631846166, 'fourier_order': 9}

# %%
## entrenamos el modelo con los best params
combined_data = pd.concat([train_data, test_data]).reset_index(drop=True)

model = Prophet(
    interval_width=best_params['interval_width'],
    changepoint_prior_scale=best_params['changepoint_prior_scale'],
    n_changepoints=best_params['n_changepoints'],
    weekly_seasonality=True,
    seasonality_mode=best_params['seasonality_mode'],
    seasonality_prior_scale=best_params['seasonality_prior_scale'],
    holidays_prior_scale=best_params['holidays_prior_scale']
)

model.add_seasonality(name='monthly', period=30.5, fourier_order=best_params['fourier_order'])
model.fit(combined_data)
# Out:
# 02:59:20 - cmdstanpy - INFO - Chain [1] start processing
# 02:59:20 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_cv = cross_validation(model, 
                         initial=f'{104 * 7} days',  #  2 años
                         period=f'{4 * 7} days',     # por mes
                         horizon=f'{52 * 7} days')   # 1 año
df_cv
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]
# 03:00:29 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:30 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:31 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:32 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:33 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:34 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:35 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:36 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:37 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:38 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] done processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] start processing
# 03:00:39 - cmdstanpy - INFO - Chain [1] done processing
#              ds         yhat   yhat_lower   yhat_upper           y     cutoff
# 0    2017-01-08   732.599867   725.467069   740.300012  730.504586 2017-01-01
# 1    2017-01-15   731.038822   723.949903   738.295031  725.766069 2017-01-01
# 2    2017-01-22   732.608231   725.482910   740.207361  717.353454 2017-01-01
# 3    2017-01-29   739.258179   732.150521   746.891393  714.414817 2017-01-01
# 4    2017-02-05   741.650250   734.523652   749.566136  710.849518 2017-01-01
# ...         ...          ...          ...          ...         ...        ...
# 3843 2023-07-09  1058.193844  1031.944349  1083.690118  904.871792 2022-08-07
# 3844 2023-07-16  1064.521948  1038.614639  1089.662200  918.623411 2022-08-07
# 3845 2023-07-23  1062.604906  1033.135424  1089.072860  919.283957 2022-08-07
# 3846 2023-07-30  1063.561678  1035.718015  1088.057015  917.182048 2022-08-07
# 3847 2023-08-06  1070.570835  1042.449416  1096.847272  938.788263 2022-08-07
#
# [3848 rows x 6 columns]

# %%
df_p = performance_metrics(df_cv)

# %%
fig = plot_cross_validation_metric(df_cv, metric="rmse")
